# %%
import os
import nltk
import ssl
import streamlit as st
import random
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

ssl._create_default_https_context=ssl._create_unverified_context
nltk.data.path.append(os.path.abspath("nltk_data"))
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\baska\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: click in c:\users\baska\appdata\local\programs\python\python312\lib\site-packages (from nltk) (8.1.7)
# Collecting joblib (from nltk)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\baska\appdata\local\programs\python\python312\lib\site-packages (from nltk) (2024.7.24)
# Requirement already satisfied: tqdm in c:\users\baska\appdata\local\programs\python\python312\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\users\baska\appdata\local\programs\python\python312\lib\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.5 MB 1.0 MB/s eta 0:00:01
#    -------------------- ------------------- 0.8/1.5 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.3/1.5 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 1.7 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Installing collected packages: joblib, nltk
# Successfully installed joblib-1.4.2 nltk-3.9.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.5.1-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\baska\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\baska\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\baska\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.5.1-cp312-cp312-win_amd64.whl (10.9 MB)
#    ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#     --------------------------------------- 0.3/10.9 MB ? eta -:--:--
#     --------------------------------------- 0.3/10.9 MB ? eta -:--:--
#    - -------------------------------------- 0.5/10.9 MB 540.5 kB/s eta 0:00:20
#    - -------------------------------------- 0.5/10.9 MB 540.5 kB/s eta 0:00:20
#    --- ------------------------------------ 1.0/10.9 MB 811.6 kB/s eta 0:00:13
#    --- ------------------------------------ 1.0/10.9 MB 811.6 kB/s eta 0:00:13
#    ---- ----------------------------------- 1.3/10.9 MB 849.0 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.6/10.9 MB 873.8 kB/s eta 0:00:11
#    -------- ------------------------------- 2.4/10.9 MB 1.1 MB/s eta 0:00:08
#    --------- ------------------------------ 2.6/10.9 MB 1.2 MB/s eta 0:00:08
#    ------------ --------------------------- 3.4/10.9 MB 1.4 MB/s eta 0:00:06
#    -------------- ------------------------- 3.9/10.9 MB 1.5 MB/s eta 0:00:05
#    ---------------- ----------------------- 4.5/10.9 MB 1.6 MB/s eta 0:00:05
#    -------------------- ------------------- 5.5/10.9 MB 1.8 MB/s eta 0:00:04
#    ---------------------- ----------------- 6.3/10.9 MB 2.0 MB/s eta 0:00:03
#    -------------------------- ------------- 7.3/10.9 MB 2.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.1/10.9 MB 2.3 MB/s eta 0:00:02
#    -------------------------------- ------- 8.9/10.9 MB 2.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.7/10.9 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  10.7/10.9 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 10.9/10.9 MB 2.5 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scikit-learn
# Successfully installed scikit-learn-1.5.1 threadpoolctl-3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import json

# Load JSON data
with open(r'C:\Users\baska\Downloads\SIH\chatbot\intents.json', 'r') as file:
    data = json.load(file)

# Print the loaded data to verify its structure
print(type(data))  # Should print <class 'dict'>
print(data.keys())  # Should show keys like 'intents'

# Check the structure inside 'intents'
print(type(data['intents']))  # Should print <class 'list'>
print(data['intents'][0])  # Should show the first intent with keys like 'tag', 'patterns', 'responses'
# Out:
# <class 'dict'>
# dict_keys(['intents'])
# <class 'list'>
# {'tag': 'greeting', 'patterns': ['Hi', 'Hello', 'Hey', 'Good morning', 'Good evening'], 'responses': ['Hello!', 'Hi there!', 'Greetings!', 'How can I help you today?']}

# %%
#vectorizer
vectorizer=TfidfVectorizer()
clf=LogisticRegression(random_state=0,max_iter=10000)

# Assuming 'data' is the dictionary containing the JSON data
intents = data['intents']  # Extract the list of intents

tags = []
patterns = []

# Iterate through each intent in the list
for intent in intents:
    for pattern in intent['patterns']:
        tags.append(intent['tag'])
        patterns.append(pattern)

# Print the results to verify
print("Tags:", tags)
print("Patterns:", patterns)
# Out:
# Tags: ['greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'thanks', 'thanks', 'thanks', 'thanks', 'about_ai', 'about_ai', 'about_ai', 'weather', 'weather', 'weather', 'name', 'name', 'name', 'age', 'age', 'age', 'ai_capabilities', 'ai_capabilities', 'ai_capabilities', 'joke', 'joke', 'joke', 'language', 'language', 'language', 'time', 'time', 'time', 'date', 'date', 'date', 'favorite_color', 'favorite_color', 'favorite_color', 'food', 'food', 'food', 'sports', 'sports', 'sports', 'hobby', 'hobby', 'hobby', 'robot', 'robot', 'robot', 'movies', 'movies', 'movies', 'music', 'music', 'music', 'funny', 'funny', 'funny', 'coding', 'coding', 'coding', 'favorite_animal', 'favorite_animal', 'favorite_animal', 'books', 'books', 'books', 'education', 'education', 'education', 'dream', 'dream', 'dream', 'relationship', 'relationship', 'relationship', 'news', 'news', 'news', 'games', 'games', 'games', 'programming_help', 'programming_help', 'programming_help', 'learning', 'learning', 'learning', 'pets', 'pets', 'pets', 'travel', 'travel', 'travel', 'exercise', 'exercise', 'exercise', 'self_driving', 'self_driving', 'self_driving', 'environment', 'environment', 'environment', 'technology', 'technology', 'technology', 'social_media', 'social_media', 'social_media', 'health', 'health', 'health', 'space', 'space', 'space', 'art', 'art', 'art', 'history', 'history', 'history', 'internet', 'internet', 'internet', 'cars', 'cars', 'cars', 'science', 'science', 'science', 'economy', 'economy', 'economy', 'mental_health', 'mental_health', 'mental_health', 'education_system', 'education_system', 'education_system', 'finance', 'finance', 'finance', 'cryptocurrency', 'cryptocurrency', 'cryptocurrency', 'work_life_balance', 'work_life_balance', 'work_life_balance', 'self_improvement', 'self_improvement', 'self_improvement', 'fashion', 'fashion', 'fashion', 'cooking', 'cooking', 'cooking', 'fitness', 'fitness', 'fitness', 'technology_advancements', 'technology_advancements', 'technology_advancements', 'machine_learning', 'machine_learning', 'machine_learning', 'travel_destinations', 'travel_destinations', 'travel_destinations', 'recipes', 'recipes', 'recipes', 'relationships', 'relationships', 'relationships', 'motivation', 'motivation', 'motivation', 'goal_setting', 'goal_setting', 'goal_setting', 'remote_work', 'remote_work', 'remote_work', 'self_care', 'self_care', 'self_care']
# Patterns: ['Hi', 'Hello', 'Hey', 'Good morning', 'Good evening', 'Bye', 'See you later', 'Goodbye', 'Catch you later', 'Thanks', 'Thank you', "That's helpful", 'I appreciate it', 'Tell me about AI', 'What is artificial intelligence?', 'Explain AI', "What's the weather like?", "How's the weather?", 'Weather forecast', 'What is your name?', 'Who are you?', 'Introduce yourself', 'How old are you?', "What's your age?", 'Tell me your age', 'What can you do?', 'What are your abilities?', 'How can you help me?', 'Tell me a joke', 'Make me laugh', 'Do you know any jokes?', 'Which languages do you speak?', 'Can you speak other languages?', 'What languages do you know?', 'What time is it?', 'Can you tell me the time?', "What's the current time?", "What's the date today?", "Tell me today's date", "What's the current date?", "What's your favorite color?", 'Do you have a favorite color?', 'Tell me your favorite color', "What's your favorite food?", 'Do you eat?', 'Tell me about your favorite food', 'Do you play sports?', "What's your favorite sport?", 'Tell me about sports', "What's your hobby?", 'What do you do for fun?', 'Tell me your hobbies', 'Are you a robot?', 'Are you human?', 'Tell me if you are a robot', 'Do you watch movies?', "What's your favorite movie?", 'Tell me about movies', 'Do you like music?', "What's your favorite song?", 'Tell me about music', 'Are you funny?', 'Can you make me laugh?', 'Tell me something funny', 'Do you code?', "What's your favorite programming language?", 'Tell me about coding', "What's your favorite animal?", 'Tell me about animals', 'Do you like animals?', 'Do you read books?', "What's your favorite book?", 'Tell me about books', "What's your education?", 'Are you educated?', 'Tell me about your learning', 'Do you dream?', 'Tell me your dreams', 'What do you dream about?', 'Are you in a relationship?', 'Do you have a girlfriend?', 'Tell me about your relationships', "What's the news?", 'Tell me the latest news', 'Do you know the news?', 'Do you play games?', "What's your favorite game?", 'Tell me about games', 'Can you help me with programming?', 'I need coding help', 'Help with programming', 'How can I learn better?', 'Tips for learning', 'Help me learn', 'Do you have pets?', "What's your favorite pet?", 'Tell me about pets', 'Do you travel?', 'Where do you like to travel?', 'Tell me about travel', 'Do you exercise?', "What's your favorite exercise?", 'Tell me about exercise', 'Tell me about self-driving cars', 'What do you think of autonomous vehicles?', 'Self-driving technology', 'What can you tell me about the environment?', 'Environmental issues', 'Climate change info', 'Tell me about new technologies', "What's the latest in tech?", 'Technology trends', "What's your opinion on social media?", 'Social media platforms', 'Tell me about social networks', 'Tell me about health', 'How to stay healthy?', 'Health tips', 'Tell me about space', "What's happening in space?", 'Space exploration news', 'Do you like art?', 'Tell me about art', "What's your favorite art form?", 'Tell me about history', 'What happened in history?', 'History facts', 'Tell me about the internet', "What's the internet?", 'Internet facts', 'Tell me about cars', "What's your favorite car?", 'Car types', 'Tell me about science', "What's new in science?", 'Science facts', 'Tell me about the economy', "What's happening in the economy?", 'Economic trends', 'Tell me about mental health', 'How to improve mental health?', 'Mental health tips', 'Tell me about the education system', 'How does education work?', 'Education trends', 'Tell me about finance', 'How to manage money?', 'Finance tips', 'Tell me about cryptocurrency', "What's Bitcoin?", 'Crypto trends', 'Tell me about work-life balance', 'How to balance work and life?', 'Work-life balance tips', 'Tell me about self-improvement', 'How to improve myself?', 'Self-improvement tips', 'Tell me about fashion', "What's trending in fashion?", 'Fashion tips', 'Tell me about cooking', "What's  ...

# %%
#train
x=vectorizer.fit_transform(patterns)
y=tags
clf.fit(x,y)
# Out:
# LogisticRegression(max_iter=10000, random_state=0)

# %%
#create chatbot

def chatbot(input_text):
    input_text=vectorizer.transform([input_text])
    tag=clf.predict(input_text)[0]
    for intent in intents:
        if intent['tag']==tag:
            response=random.choice(intent['responses'])
            return response
